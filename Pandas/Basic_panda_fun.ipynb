# %%
#import panda library first
import pandas as pd

# %%
# To read a csv file using pandas
df = pd.read_csv("test.csv")

df

# %%
# To update a cell in csv file

df.loc[0,'marks'] = 80

# where first argument (0) is the index no of row
# where second argument ('marks') is the index no of coloum

# %%
# to push the changes to the csv file with no indexing
df.to_csv('test.csv',index=False)

# %%
# Syntex to check the coloum datatype
df.dtypes

# %%
# Syntex to transpose the data
df.T

# %%
# sort data based on value 
df.sort_values(by="marks")

# sort data based on index or coloum
df.sort_index(axis=1,ascending=False) # Ascending = True in default case

# %%
# To create a code of a file from original file
df2 = df.copy()

# %%
# syntex to get specific rows and coloum in return
df.loc[[1,2],["name","city"]]
